# %%
from helpers import multiply_with_overflow, normalize, random_chunk2, Assay, AutoEncoder, IDs0, IDs1, labels,train
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
params = {'learning_rate': 0.001,
            'training_epochs': 100,
            'batch_size': 100,
            'display_step': 10}

A = AutoEncoder(params)

(e,d) = A.fit(train)
# Out:
# Epoch:0001, cost=0.027307782
# Epoch:0011, cost=0.019818634
# Epoch:0021, cost=0.018221114
# Epoch:0031, cost=0.010245291
# Epoch:0041, cost=0.007440763
# Epoch:0051, cost=0.006280904
# Epoch:0061, cost=0.005030296
# Epoch:0071, cost=0.004523045
# Epoch:0081, cost=0.003816849
# Epoch:0091, cost=0.003526859

# %%
f,a = A.display()
plt.show()
